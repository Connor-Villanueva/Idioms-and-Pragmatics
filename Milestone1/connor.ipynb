# %%
import json

# %%
DATA_PATH = "../Data/idiom_repository_all.json"

# %%
with open(DATA_PATH, "rt") as f:
    data = json.load(f)

for i in range(10):
    idiom = data[i]

    print(idiom["idiom"])
# Out:
# {'variations': [], 'idiom': "'er indoors", 'sources': ['Wiktionary'], 'entry': [{'usages': [[]], 'definition': "one's wife", 'pos': 'noun'}], 'id': 1, 'confidence': 1}
# {'variations': [], 'idiom': '10 Downing Street', 'sources': ['Wiktionary'], 'entry': [{'usages': [['... explicitly clear, in the way that 10 downing street has made it clear in the case of city academies, that it is perfectly legitimate to put people in the house of lords ...']], 'definition': 'the government of the united kingdom.', 'pos': 'proper noun'}, {'usages': [['... he declared from early in his life that he intended to be viceroy of india, as a natural stepping-stone on his way to 10 downing street.']], 'definition': 'the title or office of the prime minister.', 'pos': 'proper noun'}], 'id': 2, 'confidence': 1}
# ...
