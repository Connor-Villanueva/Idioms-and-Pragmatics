# %%
import json

# %%
DATA_PATH = "../Data/idiom_repository_all.json"

# %%
with open(DATA_PATH, "rt", encoding="utf8") as f:
    data = json.load(f)

for i in range(10):
    idiom = data[i]

    idiom_keys = idiom.keys()
    
    for ikey in idiom_keys:
        d1 = idiom[ikey]

        
        if (isinstance(d1, list)):

            # Lists can have a dictionary inside of them
            if (len(d1) == 1 and isinstance(d1[0], dict)):
                print(ikey, d1[0])
            else:
                print(ikey, d1)

        elif (isinstance(d1, str)):
            print(ikey, d1)
        elif (isinstance(d1, int)):
            print(ikey, d1)
# Out:
# variations []
# idiom 'er indoors
# sources ['Wiktionary']
# entry {'usages': [[]], 'definition': "one's wife", 'pos': 'noun'}
# id 1
# confidence 1
# variations []
# idiom 10 Downing Street
# sources ['Wiktionary']
# entry [{'usages': [['... explicitly clear, in the way that 10 downing street has made it clear in the case of city academies, that it is perfectly legitimate to put people in the house of lords ...']], 'definition': 'the government of the united kingdom.', 'pos': 'proper noun'}, {'usages': [['... he declared from early in his life that he intended to be viceroy of india, as a natural stepping-stone on his way to 10 downing street.']], 'definition': 'the title or office of the prime minister.', 'pos': 'proper noun'}]
# id 2
# confidence 1
# variations []
# idiom 11 Downing Street
# sources ['Wiktionary']
# entry [{'usages': [[]], 'definition': 'w treasury of the united kingdom.', 'pos': 'proper noun'}, {'usages': [[]], 'definition': 'the title or office of the chancellor of the exchequer.', 'pos': 'proper noun'}]
# id 3
# confidence 1
# variations []
# idiom 110 proof
# sources ['Wiktionary']
# entry {'usages': [['in those days a hollywood hero had to be 110 proof....', "then i was wondering who this bob dylan was who wrote this great song, and then i was going deeper and deeper to the stuff that's 110 proof.", 'attention must be paid to dr. ron paul, the 110-proof libertarian in the republican race.']], 'definition': 'stronger than strong.', 'pos': 'adjective'}
# id 4
# confidence 1
# variations []
# idiom 12-ounce curls
# sources ['Wiktionary']
# entry {'usages': [["don't burn out your biceps with 12-ounce curls."]], 'definition': 'drink beer.', 'pos': 'noun'}
# id 5
# confidence 1
# variations []
# idiom 15 minutes of fame
# sources ['Wiktionary']
# entry {'usages': [['by the time we went to central park, someone walking in the park said they had just seen us on fox that morning. it was like being a rock star with a whole fifteen minutes of fame. so it was fun for a time.', 'the barbershop quartet homer put together had its 15 minutes of fame before fans simply lost interest.']], 'definition': 'a very short time in the spotlight or brief flurry with fame, after which the person or subject involved is quickly forgotten.', 'pos': 'noun'}
# id 6
# confidence 1
# variations []
# idiom 1600 Pennsylvania Avenue
# sources ['Wiktionary']
# entry {'usages': [[]], 'definition': 'the current president and the closest members of his administration.', 'pos': 'proper noun'}
# id 7
# confidence 1
# variations []
# idiom 23 Skidoo Street
# sources ['Wiktionary']
# entry {'usages': [['"apply at once to xyz, 23 skidoo st., new york."', 'olive oyl: 23 skidoo street, driver.']], 'definition': 'defdate. 1900 a fictitious place or a generic place that could refer to any location.', 'pos': 'proper noun'}
# id 8
# confidence 1
# variations []
# idiom 23 skidoo
# sources ['Wiktionary']
# entry [{'usages': [['... the \'varsity quarter, who at the close of each meeting discards the conventional "i move we adjourn, sir,\'" for the more modern "23, skidoo."', 'i can imagine nothing more shocking than to hear some one use a slang expression current ten years ago, such as "23 skidoo" or "you\'re off your base".']], 'definition': 'defdate. 1908-1923 to leave, particularly quickly or at an advantageous time.', 'pos': 'phrase'}, {'usages': [[]], 'definition': 'defdate. 1908-1923 to be forced to leave quickly.', 'pos': 'phrase'}]
# id 9
# confidence 1
# variations []
# idiom 800-pound gorilla
# sources ['Wiktionary']
# entry [{'usages': [[]], 'definition': 'something dangerous, menacing, or spooky that is obvious but not addressed.', 'pos': 'noun'}, {'usages': [[]], 'definition': 'an entity that dominates its environment.', 'pos': 'noun'}]
# id 10
# confidence 1
